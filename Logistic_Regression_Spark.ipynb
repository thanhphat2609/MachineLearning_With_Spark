# %% [markdown]
# # **1. Install and import necessary libraries** #

# %%
# Install pyspark
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.0)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
# Import Spark Sesion
from pyspark.sql import SparkSession

# Import libraries for Logistic Regression
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import  LogisticRegression

# Import libraries for evaluation
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
# Create Spark Sesion
spark = SparkSession.builder.appName("LogisticRegessionwithSpark").getOrCreate()
spark.version
# Out:
# '3.5.0'

# %% [markdown]
# # **2. Read dataset into dataframe and Explore** #

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read dataset
df_drybeans = spark.read.csv("/content/drive/MyDrive/Machine_Learning_wtih_Spark/dataset/drybeans.csv", header = True, inferSchema = True)

# %%
# Show schema of dataframe
df_drybeans.printSchema()
# Out:
# root
#  |-- Area: integer (nullable = true)
#  |-- Perimeter: double (nullable = true)
#  |-- MajorAxisLength: double (nullable = true)
#  |-- MinorAxisLength: double (nullable = true)
#  |-- AspectRation: double (nullable = true)
#  |-- Eccentricity: double (nullable = true)
#  |-- ConvexArea: integer (nullable = true)
#  |-- EquivDiameter: double (nullable = true)
#  |-- Extent: double (nullable = true)
#  |-- Solidity: double (nullable = true)
#  |-- roundness: double (nullable = true)
#  |-- Compactness: double (nullable = true)
#  |-- ShapeFactor1: double (nullable = true)
#  |-- ShapeFactor2: double (nullable = true)
#  |-- ShapeFactor3: double (nullable = true)
#  |-- ShapeFactor4: double (nullable = true)
#  |-- Class: string (nullable = true)

# %%
# Show first 5 rows
df_drybeans.head(5)
# Out:
# [Row(Area=28395, Perimeter=610.291, MajorAxisLength=208.1781167, MinorAxisLength=173.888747, AspectRation=1.197191424, Eccentricity=0.549812187, ConvexArea=28715, EquivDiameter=190.1410973, Extent=0.763922518, Solidity=0.988855999, roundness=0.958027126, Compactness=0.913357755, ShapeFactor1=0.007331506, ShapeFactor2=0.003147289, ShapeFactor3=0.834222388, ShapeFactor4=0.998723889, Class='SEKER'),
#  Row(Area=28734, Perimeter=638.018, MajorAxisLength=200.5247957, MinorAxisLength=182.7344194, AspectRation=1.097356461, Eccentricity=0.411785251, ConvexArea=29172, EquivDiameter=191.2727505, Extent=0.783968133, Solidity=0.984985603, roundness=0.887033637, Compactness=0.953860842, ShapeFactor1=0.006978659, ShapeFactor2=0.003563624, ShapeFactor3=0.909850506, ShapeFactor4=0.998430331, Class='SEKER'),
#  Row(Area=29380, Perimeter=624.11, MajorAxisLength=212.8261299, MinorAxisLength=175.9311426, AspectRation=1.209712656, Eccentricity=0.562727317, ConvexArea=29690, EquivDiameter=193.4109041, Extent=0.778113248, Solidity=0.989558774, roundness=0.947849473, Compactness=0.908774239, ShapeFactor1=0.007243912, ShapeFactor2=0.003047733, ShapeFactor3=0.825870617, ShapeFactor4=0.999066137, Class='SEKER'),
#  Row(Area=30008, Perimeter=645.884, MajorAxisLength=210.557999, MinorAxisLength=182.5165157, AspectRation=1.153638059, Eccentricity=0.498615976, ConvexArea=30724, EquivDiameter=195.4670618, Extent=0.782681273, Solidity=0.976695743, roundness=0.903936374, Compactness=0.928328835, ShapeFactor1=0.007016729, ShapeFactor2=0.003214562, ShapeFactor3=0.861794425, ShapeFactor4=0.994198849, Class='SEKER'),
#  Row(Area=30140, Perimeter=620.134, MajorAxisLength=201.8478822, MinorAxisLength=190.2792788, AspectRation=1.06079802, Eccentricity=0.333679658, ConvexArea=30417, EquivDiameter=195.896503, Extent=0.773098035, Solidity=0.99089325, roundness=0.984877069, Compactness=0.970515523, ShapeFactor1=0.00669701, ShapeFactor2=0.003664972, ShapeFactor3=0.941900381, ShapeFactor4=0.999166059, Class='SEKER')]

# %%
# Print value counts for column "Class"
df_drybeans.groupBy('Class').count().orderBy('count').show()
# Out:
# +--------+-----+
# |   Class|count|
# +--------+-----+
# |  BOMBAY|  522|
# |BARBUNYA| 1322|
# |    CALI| 1630|
# |   HOROZ| 1928|
# |   SEKER| 2027|
# |    SIRA| 2636|
# |DERMASON| 3546|
# +--------+-----+

# %%
# Convert Class column from string to numerical values
indexer = StringIndexer(inputCol="Class", outputCol="label")
df_drybeans = indexer.fit(df_drybeans).transform(df_drybeans)

# %%
# 0: Dermason, 1: Sira, 2: Seker, 3: Horoz, 4: Cali, 5: Barbunya, 6: Bombay
df_drybeans.groupby("label").count().orderBy("count").show()
# Out:
# +-----+-----+
# |label|count|
# +-----+-----+
# |  6.0|  522|
# |  5.0| 1322|
# |  4.0| 1630|
# |  3.0| 1928|
# |  2.0| 2027|
# |  1.0| 2636|
# |  0.0| 3546|
# +-----+-----+

# %% [markdown]
# # **3. Identify label column and index columns** #

# %%
# Prepare feature vector
assembler = VectorAssembler(inputCols=["Area","Perimeter","Solidity","roundness","Compactness"], outputCol="features")
beans_transformed_data = assembler.transform(df_drybeans)

# %%
beans_transformed_data.select("features","label").show()
# Out:
# +--------------------+-----+
# |            features|label|
# +--------------------+-----+
# |[28395.0,610.291,...|  2.0|
# |[28734.0,638.018,...|  2.0|
# |[29380.0,624.11,0...|  2.0|
# |[30008.0,645.884,...|  2.0|
# |[30140.0,620.134,...|  2.0|
# |[30279.0,634.927,...|  2.0|
# |[30477.0,670.033,...|  2.0|
# |[30519.0,629.727,...|  2.0|
# |[30685.0,635.681,...|  2.0|
# |[30834.0,631.934,...|  2.0|
# |[30917.0,640.765,...|  2.0|
# |[31091.0,638.558,...|  2.0|
# |[31107.0,640.594,...|  2.0|
# |[31158.0,642.626,...|  2.0|
# |[31158.0,641.105,...|  2.0|
# |[31178.0,636.888,...|  2.0|
# |[31202.0,644.454,...|  2.0|
# |[31203.0,639.782,...|  2.0|
# |[31272.0,638.666,...|  2.0|
# |[31335.0,635.011,...|  2.0|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# # **4. Split data into Tran and Test data** #

# %%
(training_data, testing_data) = beans_transformed_data.randomSplit([0.7, 0.3], seed = 42)

# %%
training_data.show()
# Out:
# +-----+---------+---------------+---------------+------------+------------+----------+-------------+-----------+-----------+-----------+-----------+------------+------------+------------+------------+--------+-----+--------------------+
# | Area|Perimeter|MajorAxisLength|MinorAxisLength|AspectRation|Eccentricity|ConvexArea|EquivDiameter|     Extent|   Solidity|  roundness|Compactness|ShapeFactor1|ShapeFactor2|ShapeFactor3|ShapeFactor4|   Class|label|            features|
# +-----+---------+---------------+---------------+------------+------------+----------+-------------+-----------+-----------+-----------+-----------+------------+------------+------------+------------+--------+-----+--------------------
# |22333|  545.278|    201.0372975|    142.0385806| 1.415371068| 0.707684588|     22596|  168.6275741|0.799434422|0.988360772|0.943889116| 0.83878751| 0.009001804| 0.002748636| 0.703564486| 0.995804819|DERMASON|  0.0|[22333.0,545.278,...|
# |22428|  550.728|    196.3438847|    145.8736755| 1.345985723| 0.669346996|     22696|  168.9858471|0.811550152|0.988191752| 0.92923615|0.860662645| 0.008754409| 0.002963046| 0.740740188| 0.997025718|DERMASON|  0.0|[22428.0,550.728,...|
# |22449|  554.779|    202.2162499|    141.8289799| 1.425775255| 0.712794626|     22712|  169.0649418|0.787960688|0.988420218| 0.91657253|0.836060118| 0.009007807| 0.002714869| 0.698996521| 0.996611943|DERMASON|  0.0|[22449.0,554.779,...|
# |22688|  561.892|    207.3482325|    139.5295371| 1.486052608| 0.739711911|     22982|  169.9625217|0.746463118| 0.98720738| 0.90302626|0.819696024| 0.009139115| 0.002545043| 0.671901571| 0.998481082|DERMASON|  0.0|[22688.0,561.892,...|
# |22726|  550.994|    203.8926238|    142.3899858| 1.431930923| 0.715748915|     23071|  170.1047968|0.790662074|0.985046162|0.940673971|0.834286173| 0.008971778| 0.002681134| 0.696033418| 0.996671775|DERMASON|  0.0|[22726.0,550.994,...|
# |22745|  562.893|     196.689945|    147.6420864| 1.332207839|  0.66071867|     23132|  170.1758897|0.740638229|0.983269929|0.902078037|0.865198726| 0.008647612| 0.002989093| 0.748568835|  0.99724927|DERMASON|  0.0|[22745.0,562.893,...|
# +-----+---------+---------------+---------------+------------+------------+----------+-------------+-----------+-----------+-----------+-----------+------------+------------+------------+------------+--------+-----+--------------------+
# only showing top 20 rows

# %% [markdown]
# # **5. Build and Training Logistic Model** #

# %%
# Create instance of Logistic Regression
lr = LogisticRegression(featuresCol = "features", labelCol = "label")

# Traning model
model = lr.fit(training_data)

# %% [markdown]
# # **6. Evaluate model** #

# %%
# Make predict on test data
predictions = model.transform(testing_data)

# Show predict
predictions.show()
# Out:
# +-----+---------+---------------+---------------+------------+------------+----------+-------------+-----------+-----------+-----------+-----------+------------+------------+------------+------------+--------+-----+--------------------+--------------------+--------------------+----------+
# | Area|Perimeter|MajorAxisLength|MinorAxisLength|AspectRation|Eccentricity|ConvexArea|EquivDiameter|     Extent|   Solidity|  roundness|Compactness|ShapeFactor1|ShapeFactor2|ShapeFactor3|ShapeFactor4|   Class|label|            features|       rawPrediction|         probability|prediction|
# +-----+---------+---------------+---------------+------------+------------+----------+-------------+-----------+-----------+-----------+-----------+------------+------------+------------+------------+--------+-----+--------------------+--------------------+--------------------+----------+
# |20548|  524.736|    183.9652515|    142.6723878| 1.289424354| 0.631298586|     20825|  161.7483421|0.759686483|0.986698679|0.937772948| 0.87923312| 0.008952952| 0.003300366|  0.77305088| 0.996790631|DERMASON|  0.0|[20548.0,524.736,...|[29.0512501199609...|[0.99997706893029...|       0.0|
# |21101|  533.701|    185.3819214|    146.0322578| 1.269458709| 0.616011296|     21462|  163.9104256|0.746356819|0.983179573|0.930929662| 0.88417697| 0.008785457| 0.003312081| 0.781768915| 0.992423358|DERMASON|  0.0|[21101.0,533.701,...|[27.9298678434305...|[0.99995620067292...|       0.0|
# |22227|  544.406|    197.9233017|    143.9369164| 1.375069765| 0.686387682|     22438|  168.2269163|0.719786269| 0.99059631|0.942420897|0.849960135| 0.008904634| 0.002866752| 0.722432231| 0.993394718|DERMASON|  0.0|[22227.0,544.406,...|[29.5774571868911...|[0.99997398152638...|       0.0|
# |22298|  539.161|    191.9546902|    148.0978821| 1.296133932| 0.636198754|     22505|  168.4953868|0.736709948|0.990802044|0.963915214|0.877787287| 0.008608606| 0.003152606| 0.770510522| 0.998684832|DERMASON|  0.0|[22298.0,539.161,...|[26.5330346242001...|[0.99993956429408...|       0.0|
# |22333|  545.278|    201.0372975|    142.0385806| 1.415371068| 0.707684588|     22596|  168.6275741|0.799434422|0.988360772|0.943889116| 0.83878751| 0.009001804| 0.002748636| 0.703564486| 0.995804819|DERMASON|  0.0|[22333.0,545.278,...|[29.6652766364488...|[0.99997001250411...|       0.0|
# |22428|  550.728|    196.3438847|    145.8736755| 1.345985723| 0.669346996|     22696|  168.9858471|0.811550152|0.988191752| 0.92923615|0.860662645| 0.008754409| 0.002963046| 0.740740188| 0.997025718|DERMASON|  0.0|[22428.0,550.728,...|[29.0443544373965...|[0.99995328393214...|       0.0|
# |22449|  554.779|    202.2162499|    141.8289799| 1.425775255| 0.712794626|     22712|  169.0649418|0.787960688|0.988420218| 0.91657253|0.836060118| 0.009007807| 0.002714869| 0.698996521| 0.996611943|DERMASON|  0.0|[22449.0,554.779,...|[31.3450760668072...|[0.99995483855243...|       0.0|
# |22688|  561.892|    207.3482325|    139.5295371| 1.486052608| 0.739711911|     22982|  169.9625217|0.746463118| 0.98720738| 0.90302626|0.819696024| 0.009139115| 0.002545043| 0.671901571| 0.998481082|DERMASON|  0.0|[22688.0,561.892,...|[32.6938097287175...|[0.99993538075894...|       0.0|
# |22726|  550.994|    203.8926238|    142.3899858| 1.431930923| 0.715748915|     23071|  170.1047968|0.790662074|0.985046162|0.940673971|0.834286173| 0.008971778| 0.002681134| 0.696033418| 0.996671775|DERMASON|  0.0|[22726.0,550.994,...|[29.1225965997645...|[0.99994984476532...|       0.0|
# |22745|  562.893|     196.689945|    147.6420864| 1.332207839|  0.66071867|     23132|  170.1758897|0.740638229|0.983269929|0.902078037|0.865198726| 0.008647612| 0.002989093| 0.748568835|  0.99724927|DERMASON|  0.0|[22745.0,562.893,...|[29.1356448772014...|[0.99988594211345...|       0.0|
# +-----+---------+---------------+---------------+------------+------------+----------+-------------+-----------+-----------+-----------+-----------+------------+------------+------------+------------+--------+-----+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
# Evaluate model performance
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")
accuracy = evaluator.evaluate(predictions)
print("Accuracy = ", accuracy)
# Out:
# Accuracy =  0.9140055318078953

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedPrecision")
precision = evaluator.evaluate(predictions)
print("Precision = ", precision)
# Out:
# Precision =  0.914542510879638

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedRecall")
recall = evaluator.evaluate(predictions)
print("Recall =", recall)
# Out:
# Recall = 0.9140055318078953

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="f1")
f1_score = evaluator.evaluate(predictions)
print("F1 score = ", f1_score)
# Out:
# F1 score =  0.9141223602932477

# %% [markdown]
# # **7. Stop Spark Session** #

# %%
spark.stop()
